# %%
# imports
import nltk
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import json

from textblob import TextBlob
from textblob import Word
from nltk.stem import PorterStemmer
try:
    from nltk.corpus import stopwords
    stop = stopwords.words('english')
except:
    nltk.download('stopwords')

# %%
json_data = {}

with open('../../data/raw/yp_leilanis-lahaina-2_rws.json') as f:
    json_data = json.loads(f.read())

dataset = json_normalize(json_data['reviews'])
dataset.head()
# Out:
#        author datePublished  \
# 0  Giorgio C.    2018-10-13
# 1     Maxx C.    2018-10-05
# 2       Al D.    2018-10-04
# 3  Zachary D.    2018-09-29
# 4   Chilly P.    2018-07-10
#
#                                          description  ratingValue
# 0  Try good service, beach front so a bit loud. M...            4
# 1  When we arrived they gave us a choice of eatin...            5
# 2  Stopped in here on a Tuesday evening around 8p...            4
# 3  Hawaiian chain type restaurant with pretty dec...            4
# 4  Oh my. Where do I even begin...\n\nLet's start...            1

# %%
reviews = dataset.iloc[:,2]
reviews.head()
# Out:
# 0    Try good service, beach front so a bit loud. M...
# 1    When we arrived they gave us a choice of eatin...
# 2    Stopped in here on a Tuesday evening around 8p...
# 3    Hawaiian chain type restaurant with pretty dec...
# 4    Oh my. Where do I even begin...\n\nLet's start...
# Name: description, dtype: object

# %%
dataset['word_count'] = reviews.apply(lambda x: len(str(x).split(" ")))

# %%
dataset['chr_count'] = reviews.str.len()

# %%
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))
dataset['avg_word_len'] = reviews.apply(lambda x: avg_word(x))

# %%
dataset['num_of_stopwords'] = reviews.apply(lambda x: len([x for x in x.split() if x in stop]))

# %%
dataset['hashtags'] = reviews.apply(lambda x: len([x for x in x.split() if x.startswith('#')]))

# %%
dataset['numerics'] = reviews.apply(lambda x: len([x for x in x.split() if x.isdigit()]))

# %%
dataset['uppercase_cnt'] = reviews.apply(lambda x: len([x for x in x.split() if x.isupper()]))

# %%
dataset.head()
# Out:
#        author datePublished  \
# 0  Giorgio C.    2018-10-13
# 1     Maxx C.    2018-10-05
# 2       Al D.    2018-10-04
# 3  Zachary D.    2018-09-29
# 4   Chilly P.    2018-07-10
#
#                                          description  ratingValue  word_count  \
# 0  Try good service, beach front so a bit loud. M...            4          68
# 1  When we arrived they gave us a choice of eatin...            5         178
# 2  Stopped in here on a Tuesday evening around 8p...            4         100
# 3  Hawaiian chain type restaurant with pretty dec...            4         131
# 4  Oh my. Where do I even begin...\n\nLet's start...            1         388
#
#    chr_count  avg_word_len  num_of_stopwords  hashtags  numerics  \
# 0        447      5.371429                17         0         0
# 1        889      4.098266                79         0         1
# 2        503      4.020000                52         0         0
# ...

# %%
dataset.to_csv('../../data/processed/yp_leilanis-lahaina-2_rws_basicfeatures.csv', index=False)

# %%
dataset_test = pd.read_csv('../../data/processed/yp_leilanis-lahaina-2_rws_basicfeatures.csv')
dataset_test.head()
# Out:
#        author datePublished  \
# 0  Giorgio C.    2018-10-13
# 1     Maxx C.    2018-10-05
# 2       Al D.    2018-10-04
# 3  Zachary D.    2018-09-29
# 4   Chilly P.    2018-07-10
#
#                                          description  ratingValue  word_count  \
# 0  Try good service, beach front so a bit loud. M...            4          68
# 1  When we arrived they gave us a choice of eatin...            5         178
# 2  Stopped in here on a Tuesday evening around 8p...            4         100
# 3  Hawaiian chain type restaurant with pretty dec...            4         131
# 4  Oh my. Where do I even begin...\n\nLet's start...            1         388
#
#    chr_count  avg_word_len  num_of_stopwords  hashtags  numerics  \
# 0        447      5.371429                17         0         0
# 1        889      4.098266                79         0         1
# 2        503      4.020000                52         0         0
# ...

# %%
dataset_test2 = pd.read_csv('../../data/processed/yp_kimos-maui-lahaina_rws.csv')
dataset_test2.head()
# Out:
#    status                                            reviews
# 0       1  Kimo's never disappoints.  We come here once o...
# 1       0  I was there the first week of October and Firs...
# 2       1  This place was on my "Must Do Maui" list and i...
# 3       0  Monday night dinner here and they quickly sat ...
# 4       1  Nice view and amazing cocktails. They are loca...
