# %%
# imports
import nltk
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import json

from textblob import TextBlob
from textblob import Word
from nltk.stem import PorterStemmer
try:
    from nltk.corpus import stopwords
    stop = stopwords.words('english')
except:
    nltk.download('stopwords')

# %%
json_data = {}

with open('../../data/raw/yp_dukes-waikiki-honolulu-2_rws.json') as f:
    json_data = json.loads(f.read())

dataset = json_normalize(json_data['reviews'])
dataset.head()

reviews = dataset.iloc[:,2]
reviews.head()
# Out:
# 0    Nice meal with the family tonight at Duke's he...
# 1    Went to Dukes for dinner after my friends wedd...
# 2    My boyfriend and I went to Dukes on our first ...
# 3    Why 4 stars? Because it was touristy but conve...
# 4    Perfect evening to have an outdoor dinner on o...
# Name: description, dtype: object

# %%
dataset['word_count'] = reviews.apply(lambda x: len(str(x).split(" ")))

# %%
dataset['chr_count'] = reviews.str.len()

# %%
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))
dataset['avg_word_len'] = reviews.apply(lambda x: avg_word(x))

# %%
dataset['num_of_stopwords'] = reviews.apply(lambda x: len([x for x in x.split() if x in stop]))

# %%
dataset['hashtags'] = reviews.apply(lambda x: len([x for x in x.split() if x.startswith('#')]))

# %%
dataset['numerics'] = reviews.apply(lambda x: len([x for x in x.split() if x.isdigit()]))

# %%
dataset['uppercase_cnt'] = reviews.apply(lambda x: len([x for x in x.split() if x.isupper()]))

# %%
dataset.head()
# Out:
#        author datePublished  \
# 0    Julia M.    2018-10-07
# 1  Rebecca B.    2018-10-13
# 2    Laura H.    2018-10-09
# 3    Brett N.    2018-09-22
# 4     Lisa K.    2018-10-13
#
#                                          description  ratingValue  word_count  \
# 0  Nice meal with the family tonight at Duke's he...            4         109
# 1  Went to Dukes for dinner after my friends wedd...            1         130
# 2  My boyfriend and I went to Dukes on our first ...            2         184
# 3  Why 4 stars? Because it was touristy but conve...            4         210
# 4  Perfect evening to have an outdoor dinner on o...            5          72
#
#    chr_count  avg_word_len  num_of_stopwords  hashtags  numerics  \
# 0        657      4.972727                44         0         0
# 1        779      4.984615                59         0         0
# 2        985      4.313514                80         0         1
# 3       1085      4.193237                93         0         2
# 4        418      5.338462                18         0         0
#
#    uppercase_cnt
# 0              1
# 1              0
# 2              6
# 3              8
# 4              0

# %%
dataset.to_csv('../../data/processed/yp_dukes-waikiki-honolulu-2_rws-basicfeatures.csv')

# %%
dataset_test = pd.read_csv('../../data/processed/yp_dukes-waikiki-honolulu-2_rws-basicfeatures.csv')
dataset_test.head()
# Out:
#    Unnamed: 0      author datePublished  \
# 0           0    Julia M.    2018-10-07
# 1           1  Rebecca B.    2018-10-13
# 2           2    Laura H.    2018-10-09
# 3           3    Brett N.    2018-09-22
# 4           4     Lisa K.    2018-10-13
#
#                                          description  ratingValue  word_count  \
# 0  Nice meal with the family tonight at Duke's he...            4         109
# 1  Went to Dukes for dinner after my friends wedd...            1         130
# 2  My boyfriend and I went to Dukes on our first ...            2         184
# 3  Why 4 stars? Because it was touristy but conve...            4         210
# 4  Perfect evening to have an outdoor dinner on o...            5          72
#
#    chr_count  avg_word_len  num_of_stopwords  hashtags  numerics  \
# 0        657      4.972727                44         0         0
# 1        779      4.984615                59         0         0
# 2        985      4.313514                80         0         1
# 3       1085      4.193237                93         0         2
# 4        418      5.338462                18         0         0
#
#    uppercase_cnt
# 0              1
# 1              0
# 2              6
# 3              8
# 4              0
