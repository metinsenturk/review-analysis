# %%
# imports
import nltk
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import json

from textblob import TextBlob
from textblob import Word
from nltk.stem import PorterStemmer
try:
    from nltk.corpus import stopwords
    stop = stopwords.words('english')
except:
    nltk.download('stopwords')

# %%
json_data = {}

with open('../../data/raw/yp_kimos-maui-lahaina_rws.json') as f:
    json_data = json.loads(f.read())

dataset = json_normalize(json_data['reviews'])
dataset.head()

reviews = dataset.iloc[:,2]
reviews.head()
# Out:
# 0    Kimo's never disappoints.  We come here once o...
# 1    I was there the first week of October and Firs...
# 2    This place was on my "Must Do Maui" list and i...
# 3    Monday night dinner here and they quickly sat ...
# 4    Nice view and amazing cocktails. They are loca...
# Name: description, dtype: object

# %%
dataset['word_count'] = reviews.apply(lambda x: len(str(x).split(" ")))

# %%
dataset['chr_count'] = reviews.str.len()

# %%
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))
dataset['avg_word_len'] = reviews.apply(lambda x: avg_word(x))

# %%
dataset['num_of_stopwords'] = reviews.apply(lambda x: len([x for x in x.split() if x in stop]))

# %%
dataset['hashtags'] = reviews.apply(lambda x: len([x for x in x.split() if x.startswith('#')]))

# %%
dataset['numerics'] = reviews.apply(lambda x: len([x for x in x.split() if x.isdigit()]))

# %%
dataset['uppercase_cnt'] = reviews.apply(lambda x: len([x for x in x.split() if x.isupper()]))

# %%
dataset.head()
# Out:
#         author datePublished  \
# 0    Sarina G.    2018-08-30
# 1      Maxx C.    2018-10-05
# 2  Veronica S.    2018-10-04
# 3  Kathleen W.    2018-09-28
# 4    Bhawna J.    2018-10-01
#
#                                          description  ratingValue  word_count  \
# 0  Kimo's never disappoints.  We come here once o...            5         127
# 1  I was there the first week of October and Firs...            3         100
# 2  This place was on my "Must Do Maui" list and i...            4         149
# 3  Monday night dinner here and they quickly sat ...            3         120
# 4  Nice view and amazing cocktails. They are loca...            5          65
#
#    chr_count  avg_word_len  num_of_stopwords  hashtags  numerics  \
# 0        663      4.458333                45         0         0
# 1        488      4.277778                43         0         1
# 2        814      4.426667                65         0         0
# 3        623      4.237288                52         0         2
# 4        393      5.061538                24         0         0
#
#    uppercase_cnt
# 0              3
# 1              4
# 2              0
# 3              0
# 4              0

# %%
dataset.to_csv('../../data/processed/yp_kimos-maui-lahaina_rws_basicfeatures.csv')

# %%
dataset_test = pd.read_csv('../../data/processed/yp_kimos-maui-lahaina_rws_basicfeatures.csv')
dataset_test.head()
# Out:
#    Unnamed: 0       author datePublished  \
# 0           0    Sarina G.    2018-08-30
# 1           1      Maxx C.    2018-10-05
# 2           2  Veronica S.    2018-10-04
# 3           3  Kathleen W.    2018-09-28
# 4           4    Bhawna J.    2018-10-01
#
#                                          description  ratingValue  word_count  \
# 0  Kimo's never disappoints.  We come here once o...            5         127
# 1  I was there the first week of October and Firs...            3         100
# 2  This place was on my "Must Do Maui" list and i...            4         149
# 3  Monday night dinner here and they quickly sat ...            3         120
# 4  Nice view and amazing cocktails. They are loca...            5          65
#
#    chr_count  avg_word_len  num_of_stopwords  hashtags  numerics  \
# 0        663      4.458333                45         0         0
# 1        488      4.277778                43         0         1
# 2        814      4.426667                65         0         0
# 3        623      4.237288                52         0         2
# 4        393      5.061538                24         0         0
#
#    uppercase_cnt
# 0              3
# 1              4
# 2              0
# 3              0
# 4              0
